# %% [markdown]
# <a href="https://colab.research.google.com/github/NazHub1993/Data_Analysis_Projects/blob/main/ML_Algorithms(Wine_Dataset).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.datasets import load_iris
iris=load_iris(as_frame=True)

df=iris.frame

df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
X=df.drop('target',axis='columns')
Y=df.target

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.2)

# %% [markdown]
# #Now the question is which model to use?? And also which hyperparameters to use??
#
# #Suppose you choose SVM .Now the question is which params to use whether to use kernel='rbf' or kernel='linear' or whether you should chose the value of C??

# %%
from sklearn.model_selection import cross_val_score
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

print("SVM:",np.average(cross_val_score(SVC(),X,Y,cv=5)))
print("DecisionTreeClassifier:",np.average(cross_val_score(DecisionTreeClassifier(),X,Y,cv=5)))
print("LogisticRegression:",np.average(cross_val_score(LogisticRegression(max_iter=10000),X,Y,cv=5)))
print("RandomForestClassifier:",np.average(cross_val_score(RandomForestClassifier(),X,Y,cv=5)))
# Out:
# SVM: 0.9666666666666666
# DecisionTreeClassifier: 0.9600000000000002
# LogisticRegression: 0.9733333333333334
# RandomForestClassifier: 0.9666666666666668

# %% [markdown]
# #We can see that DecisionTree and RandomForest gives the best result . Now time for choosing the hyper params

# %%
from sklearn.model_selection import GridSearchCV
clf=GridSearchCV(
    SVC(gamma='auto'),
    {
        'C':[40,10,20],
        'kernel':['rbf','linear']
    },
    cv=5,return_train_score=False
)
clf.fit(X,Y)
clf.cv_results_
# Out:
# {'mean_fit_time': array([0.00378308, 0.00363822, 0.00356369, 0.00344296, 0.00345778,
#         0.00340748]),
#  'std_fit_time': array([1.80857527e-04, 1.05131229e-04, 2.29148034e-04, 5.85078222e-05,
#         2.07656588e-04, 6.02877573e-05]),
#  'mean_score_time': array([0.00275569, 0.00267224, 0.00265727, 0.00263867, 0.00267625,
#         0.00264969]),
#  'std_score_time': array([1.50135146e-04, 6.58431487e-05, 1.34114433e-04, 4.57809863e-05,
#         5.52582057e-05, 5.62951857e-05]),
#  'param_C': masked_array(data=[40, 40, 10, 10, 20, 20],
#               mask=[False, False, False, False, False, False],
#         fill_value=999999),
#  'param_kernel': masked_array(data=['rbf', 'linear', 'rbf', 'linear', 'rbf', 'linear'],
#               mask=[False, False, False, False, False, False],
#         fill_value=np.str_('?'),
#              dtype=object),
#  'params': [{'C': 40, 'kernel': 'rbf'},
#   {'C': 40, 'kernel': 'linear'},
#   {'C': 10, 'kernel': 'rbf'},
# ...

# %%
clf1=pd.DataFrame(clf.cv_results_)
clf1.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0       0.003783      0.000181         0.002756        0.000150       40
# 1       0.003638      0.000105         0.002672        0.000066       40
# 2       0.003564      0.000229         0.002657        0.000134       10
# 3       0.003443      0.000059         0.002639        0.000046       10
# 4       0.003458      0.000208         0.002676        0.000055       20
#
#   param_kernel                         params  split0_test_score  \
# 0          rbf     {'C': 40, 'kernel': 'rbf'}           1.000000
# 1       linear  {'C': 40, 'kernel': 'linear'}           1.000000
# 2          rbf     {'C': 10, 'kernel': 'rbf'}           0.966667
# 3       linear  {'C': 10, 'kernel': 'linear'}           1.000000
# 4          rbf     {'C': 20, 'kernel': 'rbf'}           0.966667
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# ...

# %%
clf1[['param_C','param_kernel','mean_test_score']]
# Out:
#    param_C param_kernel  mean_test_score
# 0       40          rbf         0.960000
# 1       40       linear         0.960000
# 2       10          rbf         0.980000
# 3       10       linear         0.973333
# 4       20          rbf         0.966667
# 5       20       linear         0.966667

# %%
clf.best_params_
# Out:
# {'C': 10, 'kernel': 'rbf'}

# %%
clf.best_score_
# Out:
# np.float64(0.9800000000000001)

# %% [markdown]
# ##So the hypertuning was done only for one model SVC

# %% [markdown]
# #What if you want hypertuning for multiple models??

# %% [markdown]
# #First declaring a dictionary of dictionary

# %%
model_params={
    'svm':{
        'model':SVC(gamma='auto'),
        'params':{
            'C':[1,10,20],
            'kernel':['rbf','linear']
        }
    },
    'random_forest':{
        'model':RandomForestClassifier(),
        'params':{
            'n_estimators':[1,5,10]
        }
    },
    'logistic_regression':{
        'model':LogisticRegression(solver='liblinear'),
        'params':{
            'C': [0.01, 0.1, 1, 10, 100]
        }
    }
}

# %%
scores=[]

for model_name,mp in model_params.items():
  clf=GridSearchCV(mp['model'],mp['params'],cv=5,return_train_score=False)
  clf.fit(X,Y)
  scores.append(
      {
         'model':model_name,
         'best_score':clf.best_score_,
         'best_params':clf.best_params_
      }
  )

# %%
score_df=pd.DataFrame(scores,columns=['model','best_score','best_params'])
score_df.head()
# Out:
#                  model  best_score                best_params
# 0                  svm    0.980000  {'C': 1, 'kernel': 'rbf'}
# 1        random_forest    0.966667        {'n_estimators': 1}
# 2  logistic_regression    0.980000                 {'C': 100}

# %% [markdown]
# #So trying the SVM with sbove parameters

# %%
model=SVC(C=1,kernel='rbf')
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
print(accuracy_score(y_test,y_pred))
# Out:
# 0.9333333333333333

# %%
model=LogisticRegression(C=100,max_iter=10000)
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
print(accuracy_score(y_test,y_pred))
# Out:
# 0.9666666666666667
